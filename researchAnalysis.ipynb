# %%
import pandas as pd, numpy as np

# %%
inp0 = pd.read_csv(r"C:\Users\ISG\Downloads\A Market Analysis to Assess the Potential for Baseball in India\A Market Analysis to Assess the Potential for Baseball in India.csv")
inp0.head()
# Out:
#                          Timestamp  \
# 0   2024/01/22 6:05:39 PM GMT+5:30
# 1   2024/01/24 8:45:51 PM GMT+5:30
# 2   2024/01/24 9:12:08 PM GMT+5:30
# 3   2024/01/24 9:17:22 PM GMT+5:30
# 4  2024/01/24 10:07:35 PM GMT+5:30
#
#                                      Implied consent  \
# 0  I have read the information sheet provided and...
# 1  I have read the information sheet provided and...
# 2  I have read the information sheet provided and...
# 3  I have read the information sheet provided and...
# 4  I have read the information sheet provided and...
#
#    How familiar are you with baseball?  \
# 0                                    3
# 1                                    5
# 2                                    3
# 3                                    5
# 4                                    5
#
#    On a scale from 1 to 5, how interested are you in watching or participating in baseball activities?  \
# 0                                                  1
# ...

# %%
inp0.shape
# Out:
# (100, 27)

# %%
inp0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 27 columns):
#  #   Column                                                                                                                                                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                      --------------  -----
#  0   Timestamp                                                                                                                                                                                                                   100 non-null    object
# ...

# %%
inp0.isnull().sum()
# Out:
# Timestamp                                                                                                                                                                                                                      0
# Implied consent                                                                                                                                                                                                                0
# How familiar are you with baseball?                                                                                                                                                                                            0
# On a scale from 1 to 5, how interested are you in watching or participating in baseball activities?                                                                                                                            0
# ...

# %%
inp0.isnull().sum()
# Out:
# Timestamp                                                                                                                                                                                                                      0
# Implied consent                                                                                                                                                                                                                0
# How familiar are you with baseball?                                                                                                                                                                                            0
# On a scale from 1 to 5, how interested are you in watching or participating in baseball activities?                                                                                                                            0
# ...

# %%
inp0[inp0['Please leave your email if you wish to be contacted for any queries'].isnull()]
# Out:
#                           Timestamp  \
# 0    2024/01/22 6:05:39 PM GMT+5:30
# 1    2024/01/24 8:45:51 PM GMT+5:30
# 5   2024/01/24 10:23:57 PM GMT+5:30
# 10  2024/01/24 10:38:54 PM GMT+5:30
# 12  2024/01/24 10:50:46 PM GMT+5:30
# 13  2024/01/24 10:50:59 PM GMT+5:30
# 14  2024/01/24 10:51:26 PM GMT+5:30
# 16  2024/01/24 10:55:10 PM GMT+5:30
# 18  2024/01/24 11:01:22 PM GMT+5:30
# 19  2024/01/24 11:12:49 PM GMT+5:30
# 20  2024/01/24 11:18:00 PM GMT+5:30
# 22  2024/01/24 11:24:02 PM GMT+5:30
# 25  2024/01/24 11:48:11 PM GMT+5:30
# 26  2024/01/24 11:50:51 PM GMT+5:30
# 27  2024/01/24 11:52:42 PM GMT+5:30
# 28  2024/01/25 12:02:18 AM GMT+5:30
# 29  2024/01/25 12:02:19 AM GMT+5:30
# 30  2024/01/25 12:08:46 AM GMT+5:30
# 31  2024/01/25 12:24:34 AM GMT+5:30
# 34  2024/01/25 12:45:58 AM GMT+5:30
# 35   2024/01/25 1:18:31 AM GMT+5:30
# 38   2024/01/25 5:46:11 AM GMT+5:30
# 41   2024/01/25 7:15:07 AM GMT+5:30
# 47   2024/01/25 8:10:36 AM GMT+5:30
# 48   2024/01/25 8:15:45 AM GMT+5:30
# ...

# %%
inp0['How familiar are you with baseball?'].value_counts()
# Out:
# How familiar are you with baseball?
# 5    39
# 3    18
# 2    18
# 4    13
# 1    12
# Name: count, dtype: int64

# %%
inp0['On a scale from 1 to 5, how interested are you in watching or participating in baseball activities?'].value_counts()
# Out:
# On a scale from 1 to 5, how interested are you in watching or participating in baseball activities?
# 5    43
# 4    19
# 1    13
# 3    13
# 2    12
# Name: count, dtype: int64

# %%
def get_value_counts(inp0):
    result = {}
    for column in inp0.columns:
        result[column] = inp0[column].value_counts()
    return result

result = get_value_counts(inp0)

# %%
result
# Out:
# {'Timestamp': Timestamp
#  2024/01/22 6:05:39 PM GMT+5:30     1
#  2024/01/25 10:22:47 AM GMT+5:30    1
#  2024/01/25 2:45:27 PM GMT+5:30     1
#  2024/01/25 2:31:24 PM GMT+5:30     1
#  2024/01/25 12:48:12 PM GMT+5:30    1
#                                    ..
#  2024/01/25 12:08:46 AM GMT+5:30    1
#  2024/01/25 12:02:19 AM GMT+5:30    1
#  2024/01/25 12:02:18 AM GMT+5:30    1
#  2024/01/24 11:52:42 PM GMT+5:30    1
#  2024/01/29 9:34:19 PM GMT+5:30     1
#  Name: count, Length: 100, dtype: int64,
#  'Implied consent': Implied consent
#  I have read the information sheet provided and I am happy to participate. I understand that by completing and returning this questionnaire I am consenting to be part of the research study and for my data to be used as described.    100
#  Name: count, dtype: int64,
#  'How familiar are you with baseball?': How familiar are you with baseball?
#  5    39
#  3    18
#  2    18
#  4    13
#  1    12
#  Name: count, dtype: int64,
# ...

# %%
inp0.describe()
# Out:
#        How familiar are you with baseball?  \
# count                           100.000000
# mean                              3.490000
# std                               1.459867
# min                               1.000000
# 25%                               2.000000
# 50%                               4.000000
# 75%                               5.000000
# max                               5.000000
#
#        On a scale from 1 to 5, how interested are you in watching or participating in baseball activities?  \
# count                                          100.00000
# mean                                             3.67000
# std                                              1.45682
# min                                              1.00000
# 25%                                              2.75000
# 50%                                              4.00000
# 75%                                              5.00000
# max                                              5.00000
#
# ...

# %%
inp0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 27 columns):
#  #   Column                                                                                                                                                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                      --------------  -----
#  0   Timestamp                                                                                                                                                                                                                   100 non-null    object
# ...

# %%
import pandas as pd

# Load the dataset
file_path = r"C:\Users\ISG\Downloads\A Market Analysis to Assess the Potential for Baseball in India\A Market Analysis to Assess the Potential for Baseball in India.csv"  # Replace with the actual path to the cleaned dataset
data_cleaned = pd.read_csv(file_path)
# Print column names
print(data_cleaned.columns)
# Out:
# Index(['Timestamp', 'Implied consent', 'How familiar are you with baseball?',
#        'On a scale from 1 to 5, how interested are you in watching or participating in baseball activities?',
#        'Select the aspects of baseball you find most appealing (choose all that apply)',
#        'What do you perceive as the biggest barrier to following or participating in baseball?',
#        'Where do you typically receive information about baseball?',
#        'Rank the following factors based on their importance in making baseball popular in India \nNote:\n1 being most important\n3 being the least importance [Accessibility of facilities]',
#        'Rank the following factors based on their importance in making baseball popular in India \nNote:\n1 being most important\n3 being the least importance [Media coverage]',
# ...

# %%
# Assuming the correct column names are found
contingency_table = pd.crosstab(data_cleaned['How familiar are you with baseball?'], data_cleaned['Would you be interested in participating in or attending future baseball events?'])

# Perform the Chi-Square Test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Print the results
print("Chi-Square Statistic:", chi2)
print("P-value:", p)
print("Degrees of Freedom:", dof)
print("Expected Frequencies:", expected)
# Out:
# Chi-Square Statistic: 30.304571971238634
# P-value: 0.00018670917064957733
# Degrees of Freedom: 8
# Expected Frequencies: [[ 2.16  0.84  9.  ]
#  [ 3.24  1.26 13.5 ]
#  [ 3.24  1.26 13.5 ]
#  [ 2.34  0.91  9.75]
#  [ 7.02  2.73 29.25]]

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Load the dataset
file_path = r"C:\Users\ISG\Downloads\A Market Analysis to Assess the Potential for Baseball in India\A Market Analysis to Assess the Potential for Baseball in India.csv"  # Replace with the actual path to the cleaned dataset
data_cleaned = pd.read_csv(file_path)

# Assuming 'Age Group' is the column with categorized age groups
# and 'Interested_in_baseball' is the column indicating interest (1 for interested, 0 for not interested)
# Update these column names based on your actual dataset
contingency_table = pd.crosstab(data_cleaned['Please select your age group'], data_cleaned['On a scale from 1 to 5, how interested are you in watching or participating in baseball activities?'])

# Perform the Chi-Square Test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Print the results
print(f"Chi-Square Statistic: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of Freedom: {dof}")
print("Expected Frequencies:")
print(expected)
# Out:
# Chi-Square Statistic: 12.44954926858702
# P-value: 0.4102838030431358
# Degrees of Freedom: 12
# Expected Frequencies:
# [[ 2.86  2.64  2.86  4.18  9.46]
#  [ 8.45  7.8   8.45 12.35 27.95]
#  [ 0.91  0.84  0.91  1.33  3.01]
#  [ 0.78  0.72  0.78  1.14  2.58]]

# %%
# Example mapping for categorical responses to numeric
response_mapping = {
    "Decrease interest": 1,
    "No change": 2,
    "Increase somewhat":3,
    "Increase significantly": 4,
    # Add other responses as necessary
}

# Apply the mapping to the dataset
data_cleaned['International_Success_Effect_Numeric'] = data_cleaned['How would the international success of Indian baseball teams affect your interest in the sport?'].map(response_mapping)

# Now, you can calculate the Pearson correlation coefficient with scipy.stats.pearsonr
from scipy.stats import pearsonr

# Assuming the second variable is already numeric
correlation_coefficient, p_value = pearsonr(data_cleaned['International_Success_Effect_Numeric'], data_cleaned['On a scale from 1 to 5, how interested are you in watching or participating in baseball activities?'])

# Print the correlation coefficient and p-value
print("Correlation Coefficient:", correlation_coefficient)
print("P-value:", p_value)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12016\398198818.py in ?()
#      13 # Now, you can calculate the Pearson correlation coefficient with scipy.stats.pearsonr
#      14 from scipy.stats import pearsonr
#      15
#      16 # Assuming the second variable is already numeric
# ---> 17 correlation_coefficient, p_value = pearsonr(data_cleaned['International_Success_Effect_Numeric'], data_cleaned['On a scale from 1 to 5, how interested are you in watching or participating in baseball activities?'])
#      18
#      19 # Print the correlation coefficient and p-value
#      20 print("Correlation Coefficient:", correlation_coefficient)
#
# ~\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py in ?(x, y, alternative, method)
#    4764     if n != len(y):
#    4765         raise ValueError('x and y must have the same length.')
#    4766
# ...

# %%
import pandas as pd
from scipy.stats import pearsonr

# Load the cleaned dataset
data_cleaned = pd.read_csv(file_path)

# Convert both columns to numeric, coercing errors to NaN (which converts non-numeric values to NaN)
data_cleaned['International_Success_Effect_Numeric'] = pd.to_numeric(data_cleaned['How would the international success of Indian baseball teams affect your interest in the sport?'], errors='coerce')
data_cleaned['Interest_in_Baseball'] = pd.to_numeric(data_cleaned['On a scale from 1 to 5, how interested are you in watching or participating in baseball activities?'], errors='coerce')

# Drop rows with NaN values in either column to ensure the Pearson calculation can proceed without type errors
data_cleaned.dropna(subset=['International_Success_Effect_Numeric', 'Interest_in_Baseball'], inplace=True)

# Calculate the Pearson correlation coefficient
correlation_coefficient, p_value = pearsonr(data_cleaned['International_Success_Effect_Numeric'], data_cleaned['Interest_in_Baseball'])

# Print the correlation coefficient and p-value
print("Correlation Coefficient:", correlation_coefficient)
print("P-value:", p_value)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12016\3468592300.py in ?()
#      11 # Drop rows with NaN values in either column to ensure the Pearson calculation can proceed without type errors
#      12 data_cleaned.dropna(subset=['International_Success_Effect_Numeric', 'Interest_in_Baseball'], inplace=True)
#      13
#      14 # Calculate the Pearson correlation coefficient
# ---> 15 correlation_coefficient, p_value = pearsonr(data_cleaned['International_Success_Effect_Numeric'], data_cleaned['Interest_in_Baseball'])
#      16
#      17 # Print the correlation coefficient and p-value
#      18 print("Correlation Coefficient:", correlation_coefficient)
#
# ~\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py in ?(x, y, alternative, method)
#    4764     if n != len(y):
#    4765         raise ValueError('x and y must have the same length.')
# ...

# %%
import pandas as pd
from scipy.stats import pearsonr

# Load the cleaned dataset
data_cleaned = pd.read_csv(file_path)  # Adjust the path as necessary

# Assuming the 'exposure to international sports' needs encoding, let's first check its unique values to decide on encoding
print("Unique values in 'How would the international success of Indian baseball teams affect your interest in the sport?':")
print(data_cleaned['How would the international success of Indian baseball teams affect your interest in the sport?'].unique())

# Now, based on the unique values printed, you would manually encode this column. Here's an example based on hypothetical values:
exposure_mapping = {
    "Decrease interest": 1,
    "No change": 2,
    "Increase somewhat":3,
    "Increase significantly": 4,
    # Add other mappings based on actual unique values
}

# Apply the mapping
data_cleaned['Exposure_Numeric'] = data_cleaned['How would the international success of Indian baseball teams affect your interest in the sport?'].map(exposure_mapping)

# Ensure the interest in baseball column is numeric (it should be, but this is just a double check)
data_cleaned['Interest_in_Baseball'] = pd.to_numeric(data_cleaned['On a scale from 1 to 5, how interested are you in watching or participating in baseball activities?'], errors='coerce')

# Drop rows with NaN in either of the columns of interest
data_cleaned.dropna(subset=['Exposure_Numeric', 'Interest_in_Baseball'], inplace=True)

# Calculate the Pearson correlation coefficient
correlation_coefficient, p_value = pearsonr(data_cleaned['Exposure_Numeric'], data_cleaned['Interest_in_Baseball'])

# Print the correlation coefficient and p-value
print("Correlation Coefficient:", correlation_coefficient)
print("P-value:", p_value)
# Out:
# Unique values in 'How would the international success of Indian baseball teams affect your interest in the sport?':
# ['Increase significantly' 'Increase somewhat' 'No change']
# Correlation Coefficient: 0.32496434822008846
# P-value: 0.0009709948665411126

# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np

# Load the dataset
data = pd.read_csv(r"C:\Users\ISG\Downloads\A Market Analysis to Assess the Potential for Baseball in India\multiTimelineTrends.csv")  # Update with your file path

# Convert 'Week' to a datetime object
data['Week'] = pd.to_datetime(data['Week'])

# Create a numeric time variable that represents the number of weeks since the first date
data['Time'] = (data['Week'] - data['Week'].min()).dt.days / 7

# Perform the regression analysis using 'baseball: (India)' as the dependent variable
y = data['baseball: (India)']
X = sm.add_constant(data['Time'])  # Add a constant term for the intercept

# Fit the regression model
model = sm.OLS(y, X).fit()

# Print the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:      baseball: (India)   R-squared:                       0.064
# Model:                            OLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     17.71
# Date:                Thu, 21 Mar 2024   Prob (F-statistic):           3.55e-05
# Time:                        00:34:34   Log-Likelihood:                -923.03
# No. Observations:                 262   AIC:                             1850.
# Df Residuals:                     260   BIC:                             1857.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         32.6044      1.014     32.150      0.000      30.607      34.601
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# Load your dataset
data = pd.read_csv(file_path)

# Define your dependent variable
y = data['On a scale from 1 to 5, how interested are you in watching or participating in baseball activities?']

# Define your independent variables with the actual column names
X = data[['Where do you typically receive information about baseball?', 'What do you perceive as the biggest barrier to following or participating in baseball?']]

# Setup OneHotEncoder and ColumnTransformer to handle categorical variables
column_transformer = ColumnTransformer(
    transformers=[
        ('encoder', OneHotEncoder(), ['Where do you typically receive information about baseball?', 'What do you perceive as the biggest barrier to following or participating in baseball?']),
    ],
    remainder='passthrough'  # This leaves any other column unchanged, useful if you add numerical columns later
)

# Apply one-hot encoding transformation
X_transformed = column_transformer.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_transformed, y, test_size=0.2, random_state=42)

# Initialize and train the Linear Regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions
predictions = model.predict(X_test)

# Calculate the R-squared value
r_square = r2_score(y_test, predictions)

print(f'R-Squared Value: {r_square}')
# Out:
# R-Squared Value: 0.018513427650037273

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Replace 'file_path' with the path to your dataset
file_path = r"C:\Users\ISG\Downloads\A Market Analysis to Assess the Potential for Baseball in India\A Market Analysis to Assess the Potential for Baseball in India.csv"  # Replace with the actual path to the cleaned dataset
data = pd.read_csv(file_path)

# Preview the first few rows of the dataset
#print(data.head())

# Set the visual style
sns.set_style("whitegrid")

# Plot the distribution of interest levels
plt.figure(figsize=(10, 6))
sns.countplot(x='How familiar are you with baseball?', data=data)
plt.title('Distribution of Familiarity Levels in Baseball')
plt.xlabel('Familiarity Level')
plt.ylabel('Number of Respondents')
plt.show()

# Plot the distribution of interest levels
plt.figure(figsize=(10, 6))
sns.countplot(x='On a scale from 1 to 5, how interested are you in watching or participating in baseball activities?', data=data)
plt.title('Distribution of Interest Levels in Baseball')
plt.xlabel('Interest Level')
plt.ylabel('Number of Respondents')
plt.show()
